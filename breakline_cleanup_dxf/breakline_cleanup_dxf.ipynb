# %%
#!pip install ezdxf shapely numpy

# %%
import os
import numpy as np
from shapely.geometry import LineString, Point
from shapely.strtree import STRtree
import math

# %%
# -----------------------------
# User parameters
# -----------------------------
GAP = 0.20        # half gap
PLAN_TOL = 1e-6
DEDUP_TOL = 1e-3


# -----------------------------
# Basic utilities
# -----------------------------
def lerp3(a, b, t):
    return a + t * (b - a)


# -----------------------------
# POLYLINE reader (Classic R12)
# -----------------------------
def read_r12_polylines(path):
    """
    Reads old-school DXF POLYLINE/VERTEX 3D lines.
    Returns: list of dicts {layer, handle, pts3d}
    """
    lines = []
    with open(path, "r", errors="ignore") as f:
        raw = f.readlines()

    i = 0
    n = len(raw)
    polys = []

    while i < n:
        code = raw[i].strip()
        if code == "0" and raw[i+1].strip() == "POLYLINE":
            layer, handle = "0", None
            pts = []
            i += 2

            # Read polyline header
            while i+1 < n:
                c = raw[i].strip()
                v = raw[i+1].strip()

                if c == "8":  # layer
                    layer = v
                if c == "5":  # handle
                    handle = v
                if c == "0" and v == "VERTEX":
                    break
                i += 2

            # Read vertices
            while i+1 < n:
                c = raw[i].strip()
                v = raw[i+1].strip()

                if c == "0" and v in ["SEQEND", "POLYLINE"]:
                    break

                if c == "10":
                    x = float(v)
                    y = float(raw[i+3].strip())
                    z = float(raw[i+5].strip())
                    pts.append([x, y, z])
                    i += 6
                else:
                    i += 2

            if len(pts) >= 2:
                polys.append({"layer": layer, "handle": handle, "pts3d": np.array(pts)})

        else:
            i += 1

    return polys


# -----------------------------
# Poly wrapper
# -----------------------------
class Poly3D:
    def __init__(self, pts3):
        self.coords3d = pts3
        self.coords2d = pts3[:, :2]
        seg = np.linalg.norm(np.diff(self.coords2d, axis=0), axis=1)
        self.cum2d = np.hstack([[0.0], np.cumsum(seg)])

    @property
    def length2d(self):
        return float(self.cum2d[-1])

    def point_at(self, d):
        d = max(0, min(d, self.length2d))
        idx = np.searchsorted(self.cum2d, d, side="right") - 1
        idx = int(max(0, min(idx, len(self.coords3d)-2)))
        t = (d - self.cum2d[idx]) / max(PLAN_TOL, (self.cum2d[idx+1] - self.cum2d[idx]))
        return lerp3(self.coords3d[idx], self.coords3d[idx+1], t)

    def split_intervals(self, intervals):
        """
        intervals = list of (start, end) plan distances to remove
        """
        if not intervals:
            return [self.coords3d]

        cuts = []
        for d1, d2 in intervals:
            d1 = max(0, min(self.length2d, d1))
            d2 = max(0, min(self.length2d, d2))
            if d2 > d1 + PLAN_TOL:
                cuts.append((d1, d2))

        cuts.sort()

        merged = []
        for a, b in cuts:
            if not merged or a > merged[-1][1]:
                merged.append([a, b])
            else:
                merged[-1][1] = max(merged[-1][1], b)

        keeps = []
        cursor = 0.0
        for a, b in merged:
            if cursor < a:
                keeps.append((cursor, a))
            cursor = b

        if cursor < self.length2d:
            keeps.append((cursor, self.length2d))

        segments = []
        for k1, k2 in keeps:
            p1 = self.point_at(k1)
            p2 = self.point_at(k2)
            mask = (self.cum2d > k1) & (self.cum2d < k2)
            mids = self.coords3d[mask]
            seg = np.vstack([p1, mids, p2])
            segments.append(seg)

        return segments

def resolve_index(cand, all_geoms):
    # 1. identity match
    for idx, g in enumerate(all_geoms):
        if cand is g:
            return idx

    # 2. exact geometry equality match
    if hasattr(cand, "equals"):
        for idx, g in enumerate(all_geoms):
            if g.equals(cand):
                return idx

    # 3. coordinate match (last resort)
    try:
        c0 = list(cand.coords)
        for idx, g in enumerate(all_geoms):
            if list(g.coords) == c0:
                return idx
    except Exception:
        pass

    return None

# -----------------------------
# Main processing
# -----------------------------
def trim_breaklines(input_dxf, output_dxf, gap=GAP):
    polys_raw = read_r12_polylines(input_dxf)
    if not polys_raw:
        print("No valid POLYLINE entities found")
        return

    polys = [Poly3D(p["pts3d"]) for p in polys_raw]
    lines2d = [LineString(p.coords2d.tolist()) for p in polys]
    tree = STRtree(lines2d)

    # Initialize cuts for each polyline
    cuts = [[] for _ in polys]

    for i, ls in enumerate(lines2d):
        for cand in tree.query(ls):
            j = resolve_index(cand, lines2d)
            if j is None or j <= i:
                continue

            # Compute overlapping intervals along ls and cand
            inter = ls.intersection(cand)
            if inter.is_empty:
                continue

            # Handle Point or LineString intersections
            if inter.geom_type == "Point":
                d = ls.project(inter)
                cuts[i].append((d - gap, d + gap))
            elif inter.geom_type == "MultiPoint":
                for pt in inter.geoms:
                    d = ls.project(pt)
                    cuts[i].append((d - gap, d + gap))
            elif inter.geom_type in ["LineString", "MultiLineString"]:
                lines = [inter] if inter.geom_type == "LineString" else inter.geoms
                for l in lines:
                    d0 = ls.project(LineString([l.coords[0]]))
                    d1 = ls.project(LineString([l.coords[-1]]))
                    cuts[i].append((min(d0, d1) - gap, max(d0, d1) + gap))

    # WRITE OUTPUT DXF
    with open(output_dxf, "w") as f:
        f.write("0\nSECTION\n2\nENTITIES\n")
        for idx, poly in enumerate(polys):
            segs = poly.split_intervals(cuts[idx])
            for seg in segs:
                f.write("0\nPOLYLINE\n8\n{}\n".format(polys_raw[idx]["layer"]))
                for x, y, z in seg:
                    f.write("0\nVERTEX\n8\n{}\n10\n{}\n20\n{}\n30\n{}\n".format(
                        polys_raw[idx]["layer"], x, y, z))
                f.write("0\nSEQEND\n")
        f.write("0\nENDSEC\n0\nEOF\n")

    print("Saved:", output_dxf)

# %%
# Set folder and LandXML file name.
INPUT_DIR = r'P:\2025\ARROYO DE LOS PINOS\RS\02_PRODUCTION\06_CYCLONE_3DR\Breakline'
input_dxf =  f'{INPUT_DIR}/sample.dxf'

# Create out file name
output_dxf = os.path.splitext(input_dxf)[0] + '_cleanup.dxf'

trim_breaklines(input_dxf, output_dxf, gap=GAP)
# Out:
# Saved: P:\2025\ARROYO DE LOS PINOS\RS\02_PRODUCTION\06_CYCLONE_3DR\Breakline/sample_cleanup.dxf
